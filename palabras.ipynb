# %% [markdown]
# <a href="https://colab.research.google.com/github/valvaradoo/valeria-alvarado/blob/main/palabras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
python_diccionario = {
    "False": ["Valor booleano falso.", "x = False"],
    "None": ["Representa ausencia de valor.", "x = None"],
    "True": ["Valor booleano verdadero.", "x = True"],
    "and": ["Operador lógico AND.", "x = True and False"],
    "as": ["Usado para asignar alias.", "import math as m"],
    "assert": ["Verifica condición y lanza error si es falsa.", "assert 2 + 2 == 4"],
    "break": ["Rompe un bucle.", "for i in range(5): break"],
    "class": ["Define una clase.", "class Persona: pass"],
    "continue": ["Salta a la siguiente iteración.", "for i in range(5): continue"],
    "def": ["Define una función.", "def suma(a,b): return a+b"],
    "del": ["Elimina una variable u objeto.", "x=5; del x"],
    "elif": ["Condicional adicional a if.", "if x==1: pass elif x==2: pass"],
    "else": ["Bloque alternativo.", "if x==1: pass else: pass"],
    "except": ["Captura excepciones.", "try: 1/0 except ZeroDivisionError: pass"],
    "finally": ["Bloque que siempre se ejecuta.", "try: x=1 finally: print('fin')"],
    "for": ["Bucle sobre secuencias.", "for i in range(3): print(i)"],
    "from": ["Importa parte de un módulo.", "from math import sqrt"],
    "global": ["Declara variable global.", "global x; x=10"],
    "if": ["Estructura condicional.", "if x>0: print('Positivo')"],
    "import": ["Importa módulos.", "import math"],
    "in": ["Verifica pertenencia.", "2 in [1,2,3]"],
    "is": ["Comprueba identidad de objetos.", "x is y"],
    "lambda": ["Función anónima.", "f = lambda x: x*2"],
    "nonlocal": ["Referencia variable no local en función anidada.", "def f(): x=1; def g(): nonlocal x; x=2"],
    "not": ["Operador lógico de negación.", "not True"],
    "or": ["Operador lógico OR.", "True or False"],
    "pass": ["No realiza acción.", "for i in range(3): pass"],
    "raise": ["Lanza una excepción.", "raise ValueError('error')"],
    "return": ["Devuelve valor de una función.", "def f(): return 5"],
    "try": ["Inicia bloque de manejo de errores.", "try: 1/0 except: pass"],
    "while": ["Bucle con condición.", "while x<5: x+=1"],
    "with": ["Maneja contexto de recursos.", "with open('a.txt','w') as f: f.write('ok')"],
    "yield": ["Devuelve valor en generador.", "def gen(): yield 1"],
    "abs": ["Valor absoluto.", "abs(-5)"],
    "all": ["True si todos los elementos son verdaderos.", "all([True,1,3])"],
    "any": ["True si algún elemento es verdadero.", "any([0,False,5])"],
    "bin": ["Convierte entero a binario.", "bin(8)"],
    "bool": ["Convierte a booleano.", "bool(0)"],
    "breakpoint": ["Inserta un punto de depuración.", "breakpoint()"],
    "bytearray": ["Crea un array mutable de bytes.", "bytearray(4)"],
    "bytes": ["Secuencia inmutable de bytes.", "b'Hola'"],
    "callable": ["Verifica si un objeto es invocable.", "callable(print)"],
    "chr": ["Convierte entero a carácter Unicode.", "chr(65)"],
    "classmethod": ["Define método de clase.", "class C: @classmethod def f(cls): pass"],
    "compile": ["Compila código fuente.", "compile('2+2','<string>','eval')"],
    "complex": ["Crea número complejo.", "complex(2,3)"],
    "delattr": ["Elimina atributo de un objeto.", "delattr(obj,'x')"],
    "dict": ["Crea diccionario.", "dict(a=1,b=2)"],
    "dir": ["Lista nombres en un objeto.", "dir(str)"],
    "divmod": ["Devuelve cociente y resto.", "divmod(10,3)"],
    "enumerate": ["Devuelve índice y valor en iteración.", "enumerate(['a','b'])"],
    "eval": ["Evalúa una cadena como código.", "eval('2+3')"],
    "exec": ["Ejecuta código dinámico.", "exec('x=5')"],
    "filter": ["Filtra elementos según condición.", "filter(lambda x:x>0,[1,-1])"],
    "float": ["Convierte a número flotante.", "float('3.14')"],
    "format": ["Da formato a una cadena.", "'{:.2f}'.format(3.1416)"],
    "frozenset": ["Conjunto inmutable.", "frozenset([1,2,3])"],
    "getattr": ["Obtiene atributo de objeto.", "getattr(obj,'x')"],
    "globals": ["Devuelve diccionario global.", "globals()"],
    "hasattr": ["Verifica existencia de atributo.", "hasattr(obj,'x')"],
    "hash": ["Devuelve hash de objeto.", "hash('a')"],
    "help": ["Muestra ayuda interactiva.", "help(print)"],
    "hex": ["Convierte entero a hexadecimal.", "hex(255)"],
    "id": ["Devuelve identificador único.", "id(5)"],
    "input": ["Lee entrada del usuario.", "input('Nombre: ')"],
    "int": ["Convierte a entero.", "int(3.9)"],
    "isinstance": ["Verifica tipo de objeto.", "isinstance(3,int)"],
    "issubclass": ["Comprueba herencia.", "issubclass(bool,int)"],
    "iter": ["Crea iterador.", "iter([1,2])"],
    "len": ["Devuelve longitud.", "len('hola')"],
    "list": ["Crea lista.", "list('abc')"],
    "locals": ["Diccionario local.", "locals()"],
    "map": ["Aplica función a iterable.", "map(str,[1,2])"],
    "max": ["Máximo de iterable.", "max([1,2,3])"],
    "memoryview": ["Vista de memoria.", "memoryview(b'abc')"],
    "min": ["Mínimo de iterable.", "min([1,2,3])"],
    "next": ["Obtiene siguiente elemento de iterador.", "next(iter([1]))"],
    "object": ["Clase base de todas las clases.", "object()"],
    "oct": ["Convierte entero a octal.", "oct(8)"],
    "open": ["Abre archivo.", "open('f.txt','w')"],
    "ord": ["Carácter a entero Unicode.", "ord('A')"],
    "pow": ["Potencia.", "pow(2,3)"],
    "print": ["Imprime en consola.", "print('Hola')"],
    "property": ["Crea propiedad en clase.", "property()"],
    "range": ["Genera secuencia numérica.", "range(5)"],
    "repr": ["Devuelve representación legible.", "repr(5)"],
    "reversed": ["Itera al revés.", "reversed([1,2,3])"],
    "round": ["Redondea número.", "round(3.6)"],
    "set": ["Crea conjunto.", "set([1,2,2])"],
    "setattr": ["Asigna atributo.", "setattr(obj,'x',10)"],
    "slice": ["Crea objeto de corte.", "slice(1,5)"],
    "sorted": ["Ordena iterable.", "sorted([3,1,2])"],
    "staticmethod": ["Define método estático.", "class A: @staticmethod def f(): pass"],
    "str": ["Convierte a cadena.", "str(123)"],
    "sum": ["Suma elementos.", "sum([1,2,3])"],
    "super": ["Llama método de clase padre.", "super().method()"],
    "tuple": ["Crea tupla.", "tuple([1,2])"],
    "type": ["Devuelve tipo de objeto.", "type(3)"],
    "vars": ["Devuelve dict de atributos.", "vars()"],
    "zip": ["Combina iterables.", "zip([1,2],[3,4])"],
    "ArithmeticError": ["Clase base de errores aritméticos.", "raise ArithmeticError"],
    "AssertionError": ["Error de aserción.", "raise AssertionError"],
    "AttributeError": ["Atributo inexistente.", "raise AttributeError"],
    "EOFError": ["Fin inesperado de entrada.", "raise EOFError"],
    "Exception": ["Clase base de excepciones.", "raise Exception('error')"],
    "FileNotFoundError": ["Archivo no encontrado.", "raise FileNotFoundError"],
    "FloatingPointError": ["Error de coma flotante.", "raise FloatingPointError"],
    "ImportError": ["Error al importar módulo.", "raise ImportError"],
    "IndexError": ["Índice fuera de rango.", "raise IndexError"],
    "KeyError": ["Clave inexistente en diccionario.", "raise KeyError"],
    "KeyboardInterrupt": ["Interrupción por teclado.", "raise KeyboardInterrupt"],
    "LookupError": ["Error de búsqueda.", "raise LookupError"],
    "MemoryError": ["Memoria insuficiente.", "raise MemoryError"],
    "NameError": ["Nombre no definido.", "raise NameError"],
    "NotImplementedError": ["Función sin implementar.", "raise NotImplementedError"],
    "OSError": ["Error del sistema operativo.", "raise OSError"],
    "OverflowError": ["Resultado demasiado grande.", "raise OverflowError"],
    "RecursionError": ["Recursión excesiva.", "raise RecursionError"],
    "ReferenceError": ["Referencia débil inválida.", "raise ReferenceError"],
    "RuntimeError": ["Error de ejecución.", "raise RuntimeError"],
    "StopIteration": ["Iterador sin más elementos.", "raise StopIteration"],
    "SyntaxError": ["Error de sintaxis.", "raise SyntaxError"],
    "SystemError": ["Error interno de Python.", "raise SystemError"],
    "TypeError": ["Tipo inválido.", "raise TypeError"],
    "UnboundLocalError": ["Variable local sin valor.", "raise UnboundLocalError"],
    "ValueError": ["Valor inválido.", "raise ValueError"],
    "ZeroDivisionError": ["División entre cero.", "raise ZeroDivisionError"]
}

print(f"Total de términos: {len(python_diccionario)}")
for k, v in list(python_diccionario.items())[:10]:
    print(f"{k}: {v[0]} Ejemplo: {v[1]}")
